# %% [markdown]
# # Data interpolation:
# Estimating unknown values within a dataset based on the known dataset. libraries available that can be used for interpolation such as numpy, scipy, and pandas. Here is data interpolation using Numpy library:

# %%
# 1. Linear Interpolation
import numpy as np
x = np.array ([1,2,3,4,5])
y = np.array ([2,4,6,8,10])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
## Interpolating the data using linear interpolation
x_new = np.linspace(1,5,10) #create new x values
y_interp = np.interp(x_new, x, y) # interpolate y values
print(y_interp)
# Out:
# [ 2.          2.88888889  3.77777778  4.66666667  5.55555556  6.44444444
#   7.33333333  8.22222222  9.11111111 10.        ]

# %%
plt.scatter(x_new, y_interp)

# %%
# Cubic Interpolation with scipy
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 8, 27, 64, 125])

# %%
plt.scatter(x,y)

# %%
from scipy.interpolate import interp1d

# %%
# Create a cubic interpolation function
f = interp1d (x, y, kind= 'cubic')

# %%
# Interpolate the data
x_new = np.linspace(1, 5, 10)
y_interp=f(x_new)
print(y_interp)
# Out:
# [  1.           3.01371742   6.739369    12.7037037   21.43347051
#   33.45541838  49.2962963   69.48285322  94.54183813 125.        ]

# %%
plt.scatter(x_new, y_interp)

# %%
# polynomial interpolation
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])

# %%
plt.scatter(x, y)

# %%
p = np.polyfit(x, y, 2) # fit a 2nd degreepolynomial to the data

# %%
x_new = np.linspace(1, 5, 10)
y_interp = np.polyval(p, x_new)

# %%
plt.scatter(x_new, y_interp)
